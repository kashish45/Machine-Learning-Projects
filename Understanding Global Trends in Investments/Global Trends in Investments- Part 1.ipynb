# %%
#Understanding Global trends in investments so that company can take investments decisions effectively.

# %%
# Business And Data Understanding
# Let's assume the company XYZ has 2 minor constraints for investments:
# 1. It wants to invest between 5 to 15 million USD per round of investment
# 2. It wants to invest only in English-Speaking countries because of the ease of communication with companies it would 
# invest in.


# The company wants to invest where most other investors are investing.

# %%
# # The Data for this use case has been taken from crunchbase.com
# https://www.crunchbase.com/

# %%
# Business Objective :
#     1.The objective is to identify the best sectors,countries,and a suitable investment type. The best strategy is to invest where
#     others are investing, implying that the 'best' sectors and countries are the ones'where more investors are investing'.
#     2. Investment Type Analysis
#     3. Country Analysis
#     4. Sector Analysis

# %%
# Part-1: Data Cleaning
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

rounds=pd.read_csv("rounds2.csv",encoding="ISO-8859-1")
companies=pd.read_csv('companies.txt',sep="\t",encoding="ISO-8859-1")

# %%
rounds.head()
# Out:
#                      company_permalink  \
# 0                  /organization/-fame
# 1               /ORGANIZATION/-QOUNTER
# 2               /organization/-qounter
# 3  /ORGANIZATION/-THE-ONE-OF-THEM-INC-
# 4                /organization/0-6-com
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1  /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2  /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 3  /funding-round/650b8f704416801069bb178a1418776b            venture
# 4  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
#
#   funding_round_code   funded_at  raised_amount_usd
# 0                  B  05-01-2015         10000000.0
# 1                  A  14-10-2014                NaN
# 2                NaN  01-03-2014           700000.0
# 3                  B  30-01-2014          3406878.0
# ...

# %%
rounds.shape
# Out:
# (114949, 6)

# %%
companies.head()
# Out:
#                              permalink                    name  \
# 0                  /Organization/-Fame                   #fame
# 1               /Organization/-Qounter                :Qounter
# 2  /Organization/-The-One-Of-Them-Inc-  (THE) ONE of THEM,Inc.
# 3                /Organization/0-6-Com                 0-6.com
# 4       /Organization/004-Technologies        004 Technologies
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
#
#                                        category_list     status country_code  \
# 0                                              Media  operating          IND
# 1  Application Platforms|Real Time|Social Network...  operating          USA
# 2                                  Apps|Games|Mobile  operating          NaN
# ...

# %%
companies.shape
# Out:
# (66368, 10)

# %%
companies['permalink']=companies['permalink'].str.lower()
companies.head()
# Out:
#                              permalink                    name  \
# 0                  /organization/-fame                   #fame
# 1               /organization/-qounter                :Qounter
# 2  /organization/-the-one-of-them-inc-  (THE) ONE of THEM,Inc.
# 3                /organization/0-6-com                 0-6.com
# 4       /organization/004-technologies        004 Technologies
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
#
#                                        category_list     status country_code  \
# 0                                              Media  operating          IND
# 1  Application Platforms|Real Time|Social Network...  operating          USA
# 2                                  Apps|Games|Mobile  operating          NaN
# ...

# %%
rounds['company_permalink']=rounds['company_permalink'].str.lower()
rounds.head(2)
# Out:
#         company_permalink                          funding_round_permalink  \
# 0     /organization/-fame  /funding-round/9a01d05418af9f794eebff7ace91f638
# 1  /organization/-qounter  /funding-round/22dacff496eb7acb2b901dec1dfe5633
#
#   funding_round_type funding_round_code   funded_at  raised_amount_usd
# 0            venture                  B  05-01-2015         10000000.0
# 1            venture                  A  14-10-2014                NaN

# %%
len(rounds['company_permalink'].unique())
# Out:
# 66370

# %%
#There seem to be 2 extra permalinks in rounds file

# %%
# Lets have  a look at company permalinks which are in rounds file but not in companies file
rounds['company_permalink']=rounds.company_permalink.str.encode('utf-8').str.decode('ascii','ignore')
rounds.loc[~rounds['company_permalink'].isin(companies['permalink']),:]
# Out:
#                                         company_permalink  \
# 77                                  /organization/10north
# 729                               /organization/51wofang-
# 2670                              /organization/adslinked
# 3166    /organization/aesthetic-everything-social-network
# 3291                 /organization/affluent-attach-club-2
# ...                                                   ...
# 110545                       /organization/whodats-spaces
# 113839                             /organization/zengame-
# 114946                                 /organization/eron
# 114947                               /organization/asys-2
# 114948  /organization/novatiff-reklam-ve-tantm-hizmetl...
#
#                                 funding_round_permalink   funding_round_type  \
# 77      /funding-round/b41ff7de932f8b6e5bbeed3966c0ed6a  equity_crowdfunding
# 729     /funding-round/346b9180d276a74e0fbb2825e66c6f5b              venture
# ...

# %%
len(rounds['company_permalink'].unique())
# Out:
# 66368

# %%
#Now it fits well with both the files.....

# %%
rounds.to_csv('rounds_cleaned.csv',sep=',',index=False)
companies.to_csv('companies_cleaned.csv',sep='\t',index=False)
